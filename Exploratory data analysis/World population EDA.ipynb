# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gapminder_csv_url ='http://bit.ly/2cLzoxH'
df = pd.read_csv(gapminder_csv_url)
df.head(5)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# 1. Realice un resumen estadístico de sus datos.

# %%
stats = df.describe()
stats
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %% [markdown]
# 2. Agrupe por la variable “año”. Comente respecto al resultado al usar
# groupby.

# %%
'''COMENTE: Se agrupo la informacion en un nuevo index llamado año, los paises quedaron integrados
dentro de este rango.
'''
group_year = df.groupby('year')
group_year

# %% [markdown]
# 3. Ahora obtenga la suma (la cantidad), la media y la mediana para cada
# grupo, es decir, por año.

# %%
'''Suponiendo que esta es la informacion de todos los paises, podriamos 
considerar que la informacion de la poblacion es global. '''
stats_per_year = group_year.describe()
stats_per_year
# Out:
#         pop                                                                \
#       count          mean           std       min         25%         50%
# year
# 1952  142.0  1.695040e+07  5.810086e+07   60011.0  1452026.25   3943953.0
# 1957  142.0  1.876341e+07  6.550429e+07   61325.0  1568811.25   4282942.0
# 1962  142.0  2.042101e+07  6.978865e+07   65345.0  1784362.00   4686039.5
# 1967  142.0  2.265830e+07  7.837548e+07   70787.0  2034768.50   5170175.5
# 1972  142.0  2.518998e+07  8.864682e+07   76595.0  2351191.50   5877996.5
# 1977  142.0  2.767638e+07  9.748109e+07   86796.0  2759717.25   6404036.5
# 1982  142.0  3.020730e+07  1.050986e+08   98593.0  3006286.25   7007320.0
# 1987  142.0  3.303857e+07  1.147562e+08  110812.0  3194989.50   7774861.5
# 1992  142.0  3.599092e+07  1.245026e+08  125911.0  3605992.00   8688686.5
# 1997  142.0  3.883947e+07  1.334174e+08  145608.0  3770149.75   9735063.5
# 2002  142.0  4.145759e+07  1.408483e+08  170372.0  4173506.00  10372918.5
# ...

# %% [markdown]
# 4. ¿Sabías que en 1967 en Chile se inaugura el Aeropuerto Internacional
# Arturo Merino Benítez? Usando estos datos se puede especificar un
# año y obtener un marco de datos más pequeño para el año usando la
# función get_group(). Por ejemplo, podemos obtener el marco de
# datos agrupados para el año 1967. Comenta tus resultados. Escoge
# otro año explicando el porqué de la elección y qué resultados
# obtuviste.

# %%
Aeropuerto = group_year.get_group(1967)
Aeropuerto.iloc[23]
# Out:
# country            Chile
# year                1967
# pop            8858908.0
# continent       Americas
# lifeExp           60.523
# gdpPercap    5106.654313
# Name: 279, dtype: object

# %%
'''Motivo: Es mi año de nacimiento
En 1967 la población en Chile aumento en 6 millones aproximadamente.
La expectativa de vida de las personas aumento en 16 años aproximadamente.
El PBI percapita aumento al doble.'''
Aeropuerto_1 = group_year.get_group(1997)
Aeropuerto_1.iloc[23]
# Out:
# country            Chile
# year                1997
# pop           14599929.0
# continent       Americas
# lifeExp           75.816
# gdpPercap    10118.05318
# Name: 285, dtype: object

# %% [markdown]
# Ahora con los datos anteriores construya tablas pivote según las siguientes
# instrucciones:
# 1. Construya una tabla fijando “continent”, con las funciones vistas en
# clase

# %%
tabla_pivote = df.pivot_table(values="lifeExp", index="continent")
tabla_pivote
# Out:
#              lifeExp
# continent
# Africa     48.865330
# Americas   64.658737
# Asia       60.064903
# Europe     71.903686
# Oceania    74.326208

# %% [markdown]
# 2. Realice una tabla de doble entrada, fijando “continent” y “year”.
# Comente sus resultados.

# %%
tabla_pivote = df.pivot_table( values="lifeExp",index="continent", columns="year")
tabla_pivote
# Out:
# year            1952       1957       1962       1967       1972       1977  \
# continent
# Africa     39.135500  41.266346  43.319442  45.334538  47.450942  49.580423
# Americas   53.279840  55.960280  58.398760  60.410920  62.394920  64.391560
# Asia       46.314394  49.318544  51.563223  54.663640  57.319269  59.610556
# Europe     64.408500  66.703067  68.539233  69.737600  70.775033  71.937767
# Oceania    69.255000  70.295000  71.085000  71.310000  71.910000  72.855000
#
# year            1982       1987       1992       1997       2002       2007
# continent
# Africa     51.592865  53.344788  53.629577  53.598269  53.325231  54.806038
# Americas   66.228840  68.090720  69.568360  71.150480  72.422040  73.608120
# Asia       62.617939  64.851182  66.537212  68.020515  69.233879  70.728485
# Europe     72.806400  73.642167  74.440100  75.505167  76.700600  77.648600
# Oceania    74.290000  75.320000  76.945000  78.190000  79.740000  80.719500

# %% [markdown]
# 3. Con las variables anteriores, obtenga el promedio de la variable “pop”.

# %%
tabla_pivote = df.pivot_table( values="pop",index="continent", columns="year")
tabla_pivote
# Out:
# year               1952          1957          1962          1967  \
# continent
# Africa     4.570010e+06  5.093033e+06  5.702247e+06  6.447875e+06
# Americas   1.380610e+07  1.547816e+07  1.733081e+07  1.922986e+07
# Asia       4.228356e+07  4.735699e+07  5.140476e+07  5.774736e+07
# Europe     1.393736e+07  1.459635e+07  1.534517e+07  1.603930e+07
# Oceania    5.343003e+06  5.970988e+06  6.641759e+06  7.300207e+06
#
# year               1972          1977          1982          1987  \
# continent
# Africa     7.305376e+06  8.328097e+06  9.602857e+06  1.105450e+07
# Americas   2.117537e+07  2.312271e+07  2.521164e+07  2.731016e+07
# Asia       6.518098e+07  7.225799e+07  7.909502e+07  8.700669e+07
# Europe     1.668784e+07  1.723882e+07  1.770890e+07  1.810314e+07
# Oceania    8.053050e+06  8.619500e+06  9.197425e+06  9.787208e+06
#
# year               1992          1997          2002          2007
# continent
# Africa     1.267464e+07  1.430448e+07  1.603315e+07  1.787576e+07
# ...

# %% [markdown]
# 4. Obtenga un gráfico de barras del punto 3, comente sus resultados.

# %%
continente = tabla_pivote.index
y = tabla_pivote
sns.barplot(x=continente, y = y[1967] , data= tabla_pivote,hue='continent')
plt.ylabel('Population')
plt.xlabel('Continent')
plt.title('Population by continent in 1967')
print('''El continente más poblado en 1967 era Asia. Si comparamos la población asiática 
con la suma de la población del resto del mundo, la relación sería de 1 a 1 aproximadamente.''')
# Out:
# El continente más poblado en 1967 era Asia. Si comparamos la población asiática
# con la suma de la población del resto del mundo, la relación sería de 1 a 1 aproximadamente.
